# %%
import pandas as pd

# %%
french_colonies = []

with open('data/neocolonialism/france_colonies.txt', 'r') as f:
    for line in f:
        french_colonies.append(line.strip()) 

print(french_colonies)
# Out:
# ['Algeria', 'Morocco', 'Tunisia', 'Senegal', 'Mali', 'Guinea', "Cote d'Ivoire", 'Niger', 'Burkina Faso', 'Benin', 'Mauritania', 'Togo', 'Cameroon', 'Chad', 'Central African Republic', 'Gabon', 'Republic of the Congo', 'Djibouti', 'Madagascar', 'Comoros']

# %%
for country in french_colonies:
    df = pd.read_csv(f'data/neocolonialism/countries/{country}.csv')
    print(f'\n\n{country}') 
    print(np.sort(df['Year'].unique()))
# Out:
# Algeria
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       1 for country in french_colonies:
#       2     df = pd.read_csv(f'data/neocolonialism/countries/{country}.csv')
#       3     print(f'\n\n{country}')
# ----> 4     print(df['Year'].unique().sorted())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sorted'
