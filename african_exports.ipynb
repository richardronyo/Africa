# %% [markdown]
# In this notebook I will be exploring African Export data provided by The Observatory of Economic Complexity (https://oec.world/en).
#
# As a Computer Science and Mathematics grad, my expertise in Economics is limited, but I do not let that stifle my curiosity.
#
# The dataset I got all of my data from is the trade_i_baci_a_22 dataset. This dataset uses the Harmonized System (HS), which is a system by which goods are classified. This particular dataset uses the HS which was updated in 2022.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from oec import OECClient

# %%
#Getting the Africa to Africa dataset

afr_afr = pd.read_csv('data/africa/africa_to_africa_2022.csv')
afr_afr.head(20)
# Out:
# /var/folders/2n/z9x_tw7s5yg11zzdd5536_7w0000gn/T/ipykernel_19524/4185051530.py:3: DtypeWarning: Columns (0: Exporter Country trade blocs) have mixed types. Specify dtype option on import or set low_memory=False.
#   afr_afr = pd.read_csv('data/africa/africa_to_africa_2022.csv')
#     Unnamed: 0 Exporter Continent Official ID Exporter Continent Official  \
# 0            0                             af                      Africa
# 1            1                             af                      Africa
# 2            2                             af                      Africa
# 3            3                             af                      Africa
# 4            4                             af                      Africa
# 5            5                             af                      Africa
# 6            6                             af                      Africa
# 7            7                             af                      Africa
# ...

# %%
#Checking the column types to ensure that they're not all strings
columns = afr_afr.columns

for column in columns:
    print(column, ':\t', type(afr_afr[column][0]))
# Out:
# Unnamed: 0 :	 <class 'numpy.int64'>
# Exporter Continent Official ID :	 <class 'str'>
# Exporter Continent Official :	 <class 'str'>
# Exporter Country Official ID :	 <class 'str'>
# Exporter Country Official :	 <class 'str'>
# Exporter Country trade blocs :	 <class 'str'>
# Section ID :	 <class 'numpy.int64'>
# Section :	 <class 'str'>
# HS2 ID :	 <class 'numpy.int64'>
# HS2 :	 <class 'str'>
# HS4 ID :	 <class 'numpy.int64'>
# HS4 :	 <class 'str'>
# HS6 ID :	 <class 'numpy.int64'>
# HS6 :	 <class 'str'>
# Importer Continent Official ID :	 <class 'str'>
# Importer Continent Official :	 <class 'str'>
# Importer Country Official ID :	 <class 'str'>
# Importer Country Official :	 <class 'str'>
# Importer Country trade blocs :	 <class 'float'>
# Importer Country image link :	 <class 'str'>
# Year :	 <class 'numpy.int64'>
# Quantity :	 <class 'numpy.float64'>
