# %%
import pandas as pd
import matplotlib.pyplot as plt

from oec import OECClient

# %%
oec_client = OECClient()

trade_i_baci_22_members = oec_client.get_cube_members(35, 'Exporter Continent')['members']

trade_i_baci_22_members
# Out:
# This class interacts with the OEC API
# {'name': 'Exporter Continent',
#  'caption': 'Exporter Continent',
#  'annotations': {},
#  'depth': 1,
#  'scale': None,
#  'properties': [],
#  'dtypes': {'Exporter Continent ID': 'str', 'Exporter Continent': 'str'},
#  'members': [{'key': 'af', 'caption': 'Africa'},
#   {'key': 'as', 'caption': 'Asia'},
#   {'key': 'eu', 'caption': 'Europe'},
#   {'key': 'na', 'caption': 'North America'},
#   {'key': 'oc', 'caption': 'Oceania'},
#   {'key': 'sa', 'caption': 'South America'},
#   {'key': 'xx', 'caption': 'Unknown'}]}
